# %% [markdown]
# # EDA

# %% [markdown]
#  - EDA stands for Exploratory Data Analysis. It's an approach to analyzing datasets to summarize their main characteristics, often using
#     statistical graphs and other data visualisation techniques.
#
#  - The primary goal of the EDA is to understand what the data can tell us beyond the formal modelling or hypothesis testing tasks. It
#     involves looking at the data from different angles summarising it's main features and making sense of the data.

# %%
# importio=ng majoe liberaries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('BigBasket_Clean.csv')

# %%
df
# Out:
#                                                  product  \
# 0                 Garlic Oil - Vegetarian Capsule 500 mg
# 1                                  Water Bottle - Orange
# 2                         Brass Angle Deep - Plain, No.2
# 3      Cereal Flip Lid Container/Storage Jar - Assort...
# 4                     Creme Soft Soap - For Hands & Body
# ...                                                  ...
# 27550         Wottagirl! Perfume Spray - Heaven, Classic
# 27551                                           Rosemary
# 27552                       Peri-Peri Sweet Potato Chips
# 27553                          Green Tea - Pure Original
# 27554                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# 2        Cleaning & Household               Pooja Needs
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27555 entries, 0 to 27554
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product       27555 non-null  object
#  1   category      27555 non-null  object
#  2   sub_category  27555 non-null  object
#  3   brand         27555 non-null  object
#  4   sale_price    27555 non-null  float64
#  5   market_price  27555 non-null  float64
#  6   type          27555 non-null  object
#  7   rating        27555 non-null  float64
#  8   description   27555 non-null  object
# dtypes: float64(3), object(6)
# memory usage: 1.9+ MB

# %% [markdown]
# ### Labeling columns as Numerical,Categorical or Mixed

# %% [markdown]
#  - **Numeric**: sale_price, market_price, rating
#  - **Categorical**: Category, sub_category, brand, type
#  - **Mixed**: Description, Product

# %%
df[df['product'] == 'Soft Drink']
# Out:
#           product   category          sub_category         brand  sale_price  \
# 2208   Soft Drink  Beverages  Energy & Soft Drinks  Mountain Dew      145.80
# 3287   Soft Drink  Beverages  Energy & Soft Drinks     Coca-Cola      210.00
# 4583   Soft Drink  Beverages  Energy & Soft Drinks         Pepsi       90.00
# 5446   Soft Drink  Beverages  Energy & Soft Drinks       Mirinda       64.03
# 8335   Soft Drink  Beverages  Energy & Soft Drinks         Pepsi       35.20
# 9429   Soft Drink  Beverages  Energy & Soft Drinks     Coca-Cola      160.00
# 10005  Soft Drink  Beverages  Energy & Soft Drinks         Pepsi       68.29
# 14916  Soft Drink  Beverages  Energy & Soft Drinks        Sprite      438.00
# 18812  Soft Drink  Beverages  Energy & Soft Drinks          7 Up      140.00
# 22997  Soft Drink  Beverages  Energy & Soft Drinks      Thums Up       59.40
# 24608  Soft Drink  Beverages  Energy & Soft Drinks       Mirinda      128.06
# ...

# %% [markdown]
# ### Univarient Analysis

# %% [markdown]
#  - It focuses on analyzing each feature in the dataset independently
#
#  - ***Benefits***:
#      - **Distribution Analysis**: The distribution of each feature is examined to identify shape , central tendency and dispersion
#      - **Potential Isuues**: It helps in identifying potential problems with the data such as outliers, skewnwss and missing values

# %%
df.columns
# Out:
# Index(['product', 'category', 'sub_category', 'brand', 'sale_price',
#        'market_price', 'type', 'rating', 'description'],
#       dtype='object')

# %%
df.category.value_counts()
# Out:
# category
# Beauty & Hygiene            7867
# Gourmet & World Food        4690
# Kitchen, Garden & Pets      3580
# Snacks & Branded Foods      2814
# Foodgrains, Oil & Masala    2676
# Cleaning & Household        2675
# Beverages                    885
# Bakery, Cakes & Dairy        851
# Baby Care                    610
# Fruits & Vegetables          557
# Eggs, Meat & Fish            350
# Name: count, dtype: int64

# %%
sns.barplot(y=df.category.value_counts().index,x=df.category.value_counts())
# Out:
# <Axes: xlabel='count', ylabel='category'>

# %%
sns.histplot(y=df.category)
# Out:
# <Axes: xlabel='Count', ylabel='category'>

# %%
sns.countplot(y=df.category)
# Out:
# <Axes: xlabel='count', ylabel='category'>

# %%
#Sub_Category

# %%
temp=df[df.category=='Beauty & Hygiene']

# %%
temp
# Out:
#                                                  product          category  \
# 0                 Garlic Oil - Vegetarian Capsule 500 mg  Beauty & Hygiene
# 4                     Creme Soft Soap - For Hands & Body  Beauty & Hygiene
# 6                                           Multani Mati  Beauty & Hygiene
# 7                      Hand Sanitizer - 70% Alcohol Base  Beauty & Hygiene
# 8      Biotin & Collagen Volumizing Hair Shampoo + Bi...  Beauty & Hygiene
# ...                                                  ...               ...
# 27541          Herbal Rose & Apricot Walnut Facial Scrub  Beauty & Hygiene
# 27542                    Embellish Skin Lightening Serum  Beauty & Hygiene
# 27548                        Apple Cider Vinegar Shampoo  Beauty & Hygiene
# 27550         Wottagirl! Perfume Spray - Heaven, Classic  Beauty & Hygiene
# 27554                     United Dreams Go Far Deodorant  Beauty & Hygiene
#
#             sub_category                       brand  sale_price  \
# ...

# %%
temp.sub_category.value_counts()
# Out:
# sub_category
# Skin Care              2294
# Health & Medicine      1133
# Hair Care              1028
# Fragrances & Deos      1000
# Bath & Hand Wash        996
# Men's Grooming          805
# Feminine Hygiene        285
# Oral Care               271
# Makeup                   48
# Mothers & Maternity       7
# Name: count, dtype: int64

# %%
sns.countplot(y=temp.sub_category)
# Out:
# <Axes: xlabel='count', ylabel='sub_category'>

# %%
temp_1=df[df.category=='Eggs, Meat & Fish']

# %%
sns.countplot(y=temp_1.sub_category)
# Out:
# <Axes: xlabel='count', ylabel='sub_category'>

# %%
temp_2=df[df.category=='Fruits & Vegetables']

# %%
temp_2.sub_category.value_counts()
# Out:
# sub_category
# Fresh Vegetables               168
# Fresh Fruits                   124
# Cuts & Sprouts                  95
# Exotic Fruits & Veggies         70
# Organic Fruits & Vegetables     68
# Herbs & Seasonings              24
# Flower Bouquets, Bunches         8
# Name: count, dtype: int64

# %%
sns.countplot(y=temp_2.sub_category)
# Out:
# <Axes: xlabel='count', ylabel='sub_category'>

# %%
f=temp_2.sub_category.value_counts()

# %%
f
# Out:
# sub_category
# Fresh Vegetables               168
# Fresh Fruits                   124
# Cuts & Sprouts                  95
# Exotic Fruits & Veggies         70
# Organic Fruits & Vegetables     68
# Herbs & Seasonings              24
# Flower Bouquets, Bunches         8
# Name: count, dtype: int64

# %%
plt.pie(f,labels=f.index,autopct='%1.1f%%')
plt.show()

# %%
#Histogram

# %%
sns.histplot(df.sale_price.sample(50),bins=10)
# Out:
# <Axes: xlabel='sale_price', ylabel='Count'>

# %%
sns.histplot(df.sale_price.head(50),bins=10,kde=True)
# Out:
# <Axes: xlabel='sale_price', ylabel='Count'>

# %%
sns.histplot(df.market_price.head(50),bins=10,kde=True)
# Out:
# <Axes: xlabel='market_price', ylabel='Count'>

# %%
a=df.brand.value_counts().head(10)
a
# Out:
# brand
# Fresho              638
# bb Royal            539
# BB Home             428
# DP                  250
# Fresho Signature    171
# bb Combo            168
# Amul                153
# INATUR              146
# Himalaya            141
# Dabur               138
# Name: count, dtype: int64

# %%
plt.pie(a,labels=a.index,autopct='%1.1f%%')
plt.show()

# %%
#ratings

# %%
c=df.rating.value_counts()

# %%
sns.lineplot(c)
# Out:
# <Axes: xlabel='rating', ylabel='count'>

# %%
sns.histplot(df.rating,kde=10)
# Out:
# <Axes: xlabel='rating', ylabel='Count'>

# %%
g=df[df.rating>=1].rating.value_counts()

# %%
sns.lineplot(g)
# Out:
# <Axes: xlabel='rating', ylabel='count'>

# %%
sns.scatterplot(g)
# Out:
# <Axes: xlabel='rating', ylabel='count'>

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
#  - Bivariate Analysis is a statistical method that involves the analysis of two variables simultaniously to determine the relatioship between them.
#  - It focuses on understanding how changes in one variable affect changes in another variable

# %% [markdown]
# Graph Preferences
#  - Scatterplot
#  - lineplot
#  - bubbleplots
#  - heatmap
#  - barplot
#  - pie

# %% [markdown]
# Steps:
#  - Select two columns
#  - Understanding relationship between the columns
#    - **Numerical-Numerical**: Check coorelations. You can plot graphs like lineplot, heatmaps
#    - **Ctegorical-Numerical**: Create visualisation that compare the distribution of the numerical data across different categories of the categorical data
#    - **Categorical-Categorical**: You can create a cross-tabulation of contigency tables that show the distribution of values in one categorical column grouped by the values in the other categorical column

# %%
df.columns
# Out:
# Index(['product', 'category', 'sub_category', 'brand', 'sale_price',
#        'market_price', 'type', 'rating', 'description'],
#       dtype='object')

# %% [markdown]
# ###### Numerical-Numerical

# %%
tempdf=df.head(50)

# %%
sns.scatterplot(data=tempdf,y=tempdf.market_price,x=tempdf.sale_price)
# Out:
# <Axes: xlabel='sale_price', ylabel='market_price'>

# %% [markdown]
# - Discounts are given

# %%
df['discount']=df.market_price-df.sale_price

# %%
df
# Out:
#                                                  product  \
# 0                 Garlic Oil - Vegetarian Capsule 500 mg
# 1                                  Water Bottle - Orange
# 2                         Brass Angle Deep - Plain, No.2
# 3      Cereal Flip Lid Container/Storage Jar - Assort...
# 4                     Creme Soft Soap - For Hands & Body
# ...                                                  ...
# 27550         Wottagirl! Perfume Spray - Heaven, Classic
# 27551                                           Rosemary
# 27552                       Peri-Peri Sweet Potato Chips
# 27553                          Green Tea - Pure Original
# 27554                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# 2        Cleaning & Household               Pooja Needs
# ...

# %%
tempdf=df.head(50)

# %%
sns.scatterplot(data=tempdf,x=tempdf.market_price,y=tempdf.discount)
# Out:
# <Axes: xlabel='market_price', ylabel='discount'>

# %% [markdown]
# ###### Categorical-Numerical

# %%
# Category-Rating
sns.barplot(data=df,y=df.category,x=df.rating,ci=False)
# Out:
# <Axes: xlabel='rating', ylabel='category'>

# %% [markdown]
# - Fruits and Vegetables have null ratings
# - Eggs, Meats and Fish have null ratings

# %%
df[df.category=='Snacks & Branded Foods']
# Out:
#                                                 product  \
# 26                              Granola - Happy Berries
# 28                                         Paratha Puff
# 39                           Choco Deck - Mini Delights
# 49                    Super Hot and Sweet Mango Chutney
# 53     Choco Deck - French Dessert Inspired Layered Bar
# ...                                                 ...
# 27506                        Ready To Eat Tamarind Poha
# 27513      Sandwich Biscuits Fab - Jam In Fruit Flavour
# 27525                  FunFoods Veg Mayonnaise Original
# 27547                                   Powder - Baking
# 27549                              Papad - Garlic Disco
#
#                      category              sub_category        brand  \
# 26     Snacks & Branded Foods         Breakfast Cereals   Fit & Flex
# 28     Snacks & Branded Foods   Frozen Veggies & Snacks        Switz
# 39     Snacks & Branded Foods      Chocolates & Candies      Fabelle
# ...

# %%
df.category.value_counts()
# Out:
# category
# Beauty & Hygiene            7867
# Gourmet & World Food        4690
# Kitchen, Garden & Pets      3580
# Snacks & Branded Foods      2814
# Foodgrains, Oil & Masala    2676
# Cleaning & Household        2675
# Beverages                    885
# Bakery, Cakes & Dairy        851
# Baby Care                    610
# Fruits & Vegetables          557
# Eggs, Meat & Fish            350
# Name: count, dtype: int64

# %%
sns.barplot(data=df,y=df.category,x=df.discount,ci=False)
# Out:
# <Axes: xlabel='discount', ylabel='category'>

# %%
df[df.category=='Fruits & Vegetables']
# Out:
#                              product             category  \
# 89     Sweet Corn Kernels - Chipotle  Fruits & Vegetables
# 115       Sapota - Organically Grown  Fruits & Vegetables
# 122                    Cabbage - Red  Fruits & Vegetables
# 131                     Banana - Red  Fruits & Vegetables
# 132             Chilli - Bajji, Mild  Fruits & Vegetables
# ...                              ...                  ...
# 27310                          Leeks  Fruits & Vegetables
# 27319    Tapioca - Organically Grown  Fruits & Vegetables
# 27377                 Fried Rice Mix  Fruits & Vegetables
# 27487            Broad Beans - Diced  Fruits & Vegetables
# 27491         Green Cabbage - Grated  Fruits & Vegetables
#
#                       sub_category      brand  sale_price  market_price  \
# 89                  Cuts & Sprouts  Supa Corn        55.0         55.00
# 115                   Fresh Fruits     Fresho        35.0         43.75
# ...

# %%
mrp=df.groupby('category')['market_price'].sum()

# %%
mrp
# Out:
# category
# Baby Care                    364020.00
# Bakery, Cakes & Dairy        134357.00
# Beauty & Hygiene            3882642.22
# Beverages                    240927.00
# Cleaning & Household         701150.35
# Eggs, Meat & Fish            114042.42
# Foodgrains, Oil & Masala     615833.00
# Fruits & Vegetables           35889.55
# Gourmet & World Food        1680993.95
# Kitchen, Garden & Pets      2361574.40
# Snacks & Branded Foods       396141.50
# Name: market_price, dtype: float64

# %%
srp=df.groupby('category')['sale_price'].sum()

# %%
srp
# Out:
# category
# Baby Care                    326317.17
# Bakery, Cakes & Dairy        121525.14
# Beauty & Hygiene            3294599.44
# Beverages                    212186.67
# Cleaning & Household         605043.09
# Eggs, Meat & Fish            101114.12
# Foodgrains, Oil & Masala     516916.23
# Fruits & Vegetables           28345.36
# Gourmet & World Food        1500115.31
# Kitchen, Garden & Pets      1817723.12
# Snacks & Branded Foods       364675.08
# Name: sale_price, dtype: float64

# %%
dis=(mrp-srp)/mrp*100

# %%
dis=dis.round(2)

# %%
dis=dis.sort_values()

# %%
dis
# Out:
# category
# Snacks & Branded Foods       7.94
# Bakery, Cakes & Dairy        9.55
# Baby Care                   10.36
# Gourmet & World Food        10.76
# Eggs, Meat & Fish           11.34
# Beverages                   11.93
# Cleaning & Household        13.71
# Beauty & Hygiene            15.15
# Foodgrains, Oil & Masala    16.06
# Fruits & Vegetables         21.02
# Kitchen, Garden & Pets      23.03
# dtype: float64

# %%
sns.barplot(y=dis.index,x=dis.values)
# Out:
# <Axes: ylabel='category'>

# %%
plt.pie(dis,labels=dis.index,autopct='%1.1f%%')
plt.show()

# %%
# Sub_Category and Rating
tempdf=df.head(50)

# %%
sns.barplot(data=tempdf,y=tempdf.sub_category,x=tempdf.rating,ci=False)
# Out:
# <Axes: xlabel='rating', ylabel='sub_category'>

# %%
# Brand: Top 10 Brands
df.brand.value_counts()
# Out:
# brand
# Fresho              638
# bb Royal            539
# BB Home             428
# DP                  250
# Fresho Signature    171
#                    ...
# GO CHOCO              1
# JLT                   1
# MTR FOODS             1
# Swiss Beauty          1
# Baron De Bercy        1
# Name: count, Length: 2314, dtype: int64

# %%
df.brand.value_counts().head(10)
# Out:
# brand
# Fresho              638
# bb Royal            539
# BB Home             428
# DP                  250
# Fresho Signature    171
# bb Combo            168
# Amul                153
# INATUR              146
# Himalaya            141
# Dabur               138
# Name: count, dtype: int64

# %%
sns.barplot(df,y=df.brand.value_counts().head(10).index,x=df.brand.value_counts().head(10).values)
# Out:
# <Axes: ylabel='brand'>

# %%
plt.pie(df.brand.value_counts().head(10),labels=df.brand.value_counts().head(10).index,autopct='%1.1f%%')
plt.show()

# %%
temp=df.groupby('brand')['rating'].mean()

# %%
tempx=temp.head(50).sort_values(ascending=False)

# %%
sns.barplot(y=tempx.head(20).index,x=tempx.head(20).values)
# Out:
# <Axes: ylabel='brand'>

# %%
#Type and Rating

# %%
temp=df.groupby('type')['rating'].mean()

# %%
tempx=temp.head(20).sort_values(ascending=False)

# %%
sns.barplot(y=tempx.head(15).index,x=tempx.head(15).values)
# Out:
# <Axes: ylabel='type'>

# %%
tempc=temp.head(20)

# %%
sns.barplot(y=tempc.index,x=tempc.head(15).values)
# Out:
# <Axes: ylabel='type'>

# %% [markdown]
# ## MultiVariant Analysis

# %% [markdown]
# - Multivariant Analysis is a statistical method used to analyze and understand relationship, patterns, and interactions among multiple variables withina data set simultaniously
# - It involves examining the collective influence of several variables on one another and on the outcomes of interest

# %% [markdown]
# #Types of Graphs
# - Bubble plot
# - Cluster plot
# - barplot

# %%
px.scatter(df.head(50),y='market_price',x='sale_price',color='category')

# %%
px.scatter(df.head(50),y='market_price',x='sale_price',color='category',size='discount')

# %%
px.scatter(df.head(50),y='market_price',x='sale_price',color='category',size='rating')

# %%
px.bar(df.head(20),x='category',y='rating',color='type')

# %%
sns.catplot(data=df.head(10),y='category',x='rating',hue='type',kind='bar')
